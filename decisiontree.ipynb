# %%
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
df=pd.read_csv("/home/ps/Downloads/melbhousingdata/melb_data.csv")
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df=df.dropna(axis=0)

# %%
df.head()
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 4  Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 6  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 1  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0      ...            2.0  0.0     134.0
# 4  4/06/2016       2.5    3067.0      ...            1.0  2.0     120.0
# 6  7/05/2016       2.5    3067.0      ...            2.0  0.0     245.0
# 7  8/10/2016       2.5    3067.0      ...            1.0  2.0     256.0
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
y=df.Price

# %%
df_features=['Rooms','Price','Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

# %%
X=df[df_features]

# %%
X.describe
# Out:
# <bound method NDFrame.describe of        Rooms      Price  Bathroom  Landsize  Lattitude  Longtitude
# 1          2  1035000.0       1.0     156.0  -37.80790   144.99340
# 2          3  1465000.0       2.0     134.0  -37.80930   144.99440
# 4          4  1600000.0       1.0     120.0  -37.80720   144.99410
# 6          3  1876000.0       2.0     245.0  -37.80240   144.99930
# 7          2  1636000.0       1.0     256.0  -37.80600   144.99540
# 9          2  1097000.0       1.0     220.0  -37.80100   144.99890
# 11         3  1350000.0       2.0     214.0  -37.80850   144.99640
# 12         2   750000.0       2.0       0.0  -37.80780   144.99650
# 15         2  1310000.0       1.0     238.0  -37.80900   144.99760
# 16         3  1200000.0       2.0     113.0  -37.80560   144.99300
# 17         3  1176500.0       1.0     138.0  -37.80210   144.99650
# 19         2   890000.0       1.0     150.0  -37.80110   145.00040
# 20         4  1330000.0       2.0     780.0  -37.80730   144.99520
# ...

# %%
X.head()
# Out:
#    Rooms      Price  Bathroom  Landsize  Lattitude  Longtitude
# 1      2  1035000.0       1.0     156.0   -37.8079    144.9934
# 2      3  1465000.0       2.0     134.0   -37.8093    144.9944
# 4      4  1600000.0       1.0     120.0   -37.8072    144.9941
# 6      3  1876000.0       2.0     245.0   -37.8024    144.9993
# 7      2  1636000.0       1.0     256.0   -37.8060    144.9954

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
df_model=DecisionTreeRegressor(random_state=1)

# %%
df_model.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=1, splitter='best')

# %%
print("Making Predictions for first few Houses")
# Out:
# Making Predictions for first few Houses

# %%
print(X.head())
print("The Prediction Are")
print(df_model.predict(X.head()))
# Out:
#    Rooms      Price  Bathroom  Landsize  Lattitude  Longtitude
# 1      2  1035000.0       1.0     156.0   -37.8079    144.9934
# 2      3  1465000.0       2.0     134.0   -37.8093    144.9944
# 4      4  1600000.0       1.0     120.0   -37.8072    144.9941
# 6      3  1876000.0       2.0     245.0   -37.8024    144.9993
# 7      2  1636000.0       1.0     256.0   -37.8060    144.9954
# The Prediction Are
# [1035000. 1465000. 1600000. 1876000. 1636000.]
